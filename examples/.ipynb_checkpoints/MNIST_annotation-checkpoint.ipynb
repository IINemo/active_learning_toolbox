# %%
# %load_ext autoreload
# %autoreload 2

import os, sys
os.environ['CUDA_VISIBLE_DEVICES'] = ''

import matplotlib.pyplot as plt, collections, logging
import pandas as pd
import numpy as np

# from keras.datasets import mnist
# from keras.models import Sequential
# from keras.layers import Dense
# from keras.layers import Dropout
# from keras.utils import np_utils

import actleto
# from actleexdt.jupyter_al_annotator.active_learner import ActiveLearner, make_actlib_stg_ctor
# from libact.query_strategies import UncertaintySampling
# from libact.models import LogisticRegression as LibActLogisticRegression
# #from exdt.al_query_strategies.query_strategy_mperr import MostErroneuousNegative
# from sklearn.metrics import accuracy_score, f1_score
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.metrics import f1_score, precision_score, recall_score

# %%
(X_train_orig, y_train_orig), (X_test_orig, y_test_orig) = mnist.load_data()

# flatten 28*28 images to a 784 vector for each image
num_pixels = X_train_orig.shape[1] * X_train_orig.shape[2]
X_train = X_train_orig.reshape(X_train_orig.shape[0], num_pixels).astype('float32')
X_test = X_test_orig.reshape(X_test_orig.shape[0], num_pixels).astype('float32')

# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# one hot encode outputs
y_train = np_utils.to_categorical(y_train_orig)
y_test = np_utils.to_categorical(y_test_orig)
num_classes = y_test.shape[1]

# %%
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
    model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
y_seed = pd.Series(y_train)
unknown_indexes = np.random.randint(y_train.shape[0], size = y_train.shape[0] - 500)
y_seed.iloc[unknown_indexes] = None

# %%
model_al = KerasClassifier(build_fn = baseline_model, verbose = 0)
#model_al = LogisticRegression(penalty='l1', class_weight={True : 100.0, False : 1.0})
active_learn_alg_ctor = make_actlib_stg_ctor(lambda trn_ds: 
                                             UncertaintySampling(trn_ds, model = SklearnProbaAdapter(model_al)))
model_evaluate = KerasClassifier(build_fn = baseline_model, verbose = 0)


def f1_macro(y_t, y_p):
    return f1_score(y_t, y_p, average = 'macro')


active_learner = ActiveLearner(active_learn_alg_ctor = active_learn_alg_ctor,
                               y_dtype = 'int',
                               X_full_dataset = X_train, 
                               y_full_dataset = y_seed.values,
                               X_test_dataset = X_test,
                               y_test_dataset = y_test_orig,
                               model_evaluate = model_evaluate,
                               eval_metrics = [accuracy_score, f1_macro],
                               rnd_start_steps = 0)

X_helper = pd.DataFrame(X_train_orig.reshape(-1, 28*28), index = range(X_train_orig.shape[0]))
# Out:
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:80: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   legal_params += inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2289: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))

# %%
from exdt.jupyter_al_annotator.active_learner_ui_widget import ActiveLearnerUiWidget
from exdt.jupyter_al_annotator.visualizer_image import VisualizerImage

try:
    if active_learn_ui:
        active_learn_ui.stop()
except NameError:
    pass
    
active_learn_ui = ActiveLearnerUiWidget(active_learner = active_learner, 
                                        X_helper = X_helper,
                                        display_feature_table = False,
                                        drop_labels = list(range(0, X_helper.shape[1])),
                                        visualizer = VisualizerImage(rng = (0, X_helper.shape[1]), 
                                                                     img_shape = (28, 28),
                                                                     img_format = 'L',
                                                                     preview_shape = (100, 100)),
                                        y_labels = {str(elem) : elem for elem in range(10)},
                                        save_path = '../data/defterms_dump/results/mnist.npy',
                                        save_time = 120,
                                        logger = logger)

active_learn_ui
# Out:
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2289: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# 2017-09-13 10:04:51,721 - root - INFO - Iteration #0
# 2017-09-13 10:04:51,793 - root - INFO - Number of training samples: 504
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# 2017-09-13 10:04:53,715 - root - INFO - Evaluation:
# accuracy_score  f1_macro
#         0.8862  0.884113
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/utils/generic_utils.py:135: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   arg_spec = inspect.getargspec(cls.from_config)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/keras/wrappers/scikit_learn.py:166: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   fn_args = inspect.getargspec(fn)[0]
# 2017-09-13 10:05:01,911 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist.npy
# 2017-09-13 10:06:23,371 - root - INFO - Autosave.
# 2017-09-13 10:06:23,380 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:08:23,382 - root - INFO - Autosave.
# 2017-09-13 10:08:23,391 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:10:23,393 - root - INFO - Autosave.
# 2017-09-13 10:10:23,401 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:12:23,404 - root - INFO - Autosave.
# 2017-09-13 10:12:23,411 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:14:23,414 - root - INFO - Autosave.
# 2017-09-13 10:14:23,422 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:16:23,424 - root - INFO - Autosave.
# 2017-09-13 10:16:23,432 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:18:23,434 - root - INFO - Autosave.
# 2017-09-13 10:18:23,442 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:20:23,444 - root - INFO - Autosave.
# 2017-09-13 10:20:23,453 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:22:23,455 - root - INFO - Autosave.
# 2017-09-13 10:22:23,462 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:24:23,465 - root - INFO - Autosave.
# 2017-09-13 10:24:23,473 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:26:23,476 - root - INFO - Autosave.
# 2017-09-13 10:26:23,483 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:28:23,486 - root - INFO - Autosave.
# 2017-09-13 10:28:23,494 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:30:23,497 - root - INFO - Autosave.
# 2017-09-13 10:30:23,504 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:32:23,506 - root - INFO - Autosave.
# 2017-09-13 10:32:23,514 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:34:23,517 - root - INFO - Autosave.
# 2017-09-13 10:34:23,525 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:36:23,527 - root - INFO - Autosave.
# 2017-09-13 10:36:23,535 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:38:23,537 - root - INFO - Autosave.
# 2017-09-13 10:38:23,545 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:40:23,548 - root - INFO - Autosave.
# 2017-09-13 10:40:23,555 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:42:23,558 - root - INFO - Autosave.
# 2017-09-13 10:42:23,566 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:44:23,569 - root - INFO - Autosave.
# 2017-09-13 10:44:23,577 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:46:23,579 - root - INFO - Autosave.
# 2017-09-13 10:46:23,588 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:48:23,590 - root - INFO - Autosave.
# 2017-09-13 10:48:23,598 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:50:23,601 - root - INFO - Autosave.
# 2017-09-13 10:50:23,608 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:52:23,611 - root - INFO - Autosave.
# 2017-09-13 10:52:23,619 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:54:23,621 - root - INFO - Autosave.
# 2017-09-13 10:54:23,629 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:56:23,632 - root - INFO - Autosave.
# 2017-09-13 10:56:23,640 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 10:58:23,642 - root - INFO - Autosave.
# 2017-09-13 10:58:23,651 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:00:23,653 - root - INFO - Autosave.
# 2017-09-13 11:00:23,660 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:02:23,663 - root - INFO - Autosave.
# 2017-09-13 11:02:23,670 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:04:23,673 - root - INFO - Autosave.
# 2017-09-13 11:04:23,680 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:06:23,683 - root - INFO - Autosave.
# 2017-09-13 11:06:23,691 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:08:23,693 - root - INFO - Autosave.
# 2017-09-13 11:08:23,701 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:10:23,703 - root - INFO - Autosave.
# 2017-09-13 11:10:23,708 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:12:23,709 - root - INFO - Autosave.
# 2017-09-13 11:12:23,717 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:14:23,719 - root - INFO - Autosave.
# 2017-09-13 11:14:23,728 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:16:23,730 - root - INFO - Autosave.
# 2017-09-13 11:16:23,738 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:18:23,741 - root - INFO - Autosave.
# 2017-09-13 11:18:23,749 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:20:23,751 - root - INFO - Autosave.
# 2017-09-13 11:20:23,774 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:22:23,776 - root - INFO - Autosave.
# 2017-09-13 11:22:23,785 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:24:23,787 - root - INFO - Autosave.
# 2017-09-13 11:24:23,795 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:26:23,798 - root - INFO - Autosave.
# 2017-09-13 11:26:23,806 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:28:23,809 - root - INFO - Autosave.
# 2017-09-13 11:28:23,816 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:30:23,819 - root - INFO - Autosave.
# 2017-09-13 11:30:23,827 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:32:23,829 - root - INFO - Autosave.
# 2017-09-13 11:32:23,837 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:34:23,839 - root - INFO - Autosave.
# 2017-09-13 11:34:23,848 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:36:23,850 - root - INFO - Autosave.
# 2017-09-13 11:36:23,858 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:38:23,860 - root - INFO - Autosave.
# 2017-09-13 11:38:23,868 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:40:23,870 - root - INFO - Autosave.
# 2017-09-13 11:40:23,879 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:42:23,882 - root - INFO - Autosave.
# 2017-09-13 11:42:23,889 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:44:23,892 - root - INFO - Autosave.
# 2017-09-13 11:44:23,900 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:46:23,902 - root - INFO - Autosave.
# 2017-09-13 11:46:23,910 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:48:23,912 - root - INFO - Autosave.
# 2017-09-13 11:48:23,921 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:50:23,924 - root - INFO - Autosave.
# 2017-09-13 11:50:23,932 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:52:23,934 - root - INFO - Autosave.
# 2017-09-13 11:52:23,942 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:54:23,944 - root - INFO - Autosave.
# 2017-09-13 11:54:23,953 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:56:23,956 - root - INFO - Autosave.
# 2017-09-13 11:56:23,963 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 11:58:23,965 - root - INFO - Autosave.
# 2017-09-13 11:58:23,974 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:00:23,976 - root - INFO - Autosave.
# 2017-09-13 12:00:23,984 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:02:23,986 - root - INFO - Autosave.
# 2017-09-13 12:02:23,995 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:04:23,997 - root - INFO - Autosave.
# 2017-09-13 12:04:24,005 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:06:24,008 - root - INFO - Autosave.
# 2017-09-13 12:06:24,016 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:08:24,018 - root - INFO - Autosave.
# 2017-09-13 12:08:24,026 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:10:24,029 - root - INFO - Autosave.
# 2017-09-13 12:10:24,037 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:12:24,039 - root - INFO - Autosave.
# 2017-09-13 12:12:24,047 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:14:24,049 - root - INFO - Autosave.
# 2017-09-13 12:14:24,058 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:16:24,060 - root - INFO - Autosave.
# 2017-09-13 12:16:24,068 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:18:24,070 - root - INFO - Autosave.
# 2017-09-13 12:18:24,079 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:20:24,082 - root - INFO - Autosave.
# 2017-09-13 12:20:24,090 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:22:24,092 - root - INFO - Autosave.
# 2017-09-13 12:22:24,100 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:24:24,103 - root - INFO - Autosave.
# 2017-09-13 12:24:24,111 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:26:24,114 - root - INFO - Autosave.
# 2017-09-13 12:26:24,122 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:28:24,124 - root - INFO - Autosave.
# 2017-09-13 12:28:24,133 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:30:24,136 - root - INFO - Autosave.
# 2017-09-13 12:30:24,144 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:32:24,146 - root - INFO - Autosave.
# 2017-09-13 12:32:24,155 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:34:24,158 - root - INFO - Autosave.
# 2017-09-13 12:34:24,165 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:36:24,168 - root - INFO - Autosave.
# 2017-09-13 12:36:24,177 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:38:24,180 - root - INFO - Autosave.
# 2017-09-13 12:38:24,188 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:40:24,190 - root - INFO - Autosave.
# 2017-09-13 12:40:24,199 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:42:24,201 - root - INFO - Autosave.
# 2017-09-13 12:42:24,209 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:44:24,212 - root - INFO - Autosave.
# 2017-09-13 12:44:24,220 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:46:24,223 - root - INFO - Autosave.
# 2017-09-13 12:46:24,231 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:48:24,233 - root - INFO - Autosave.
# 2017-09-13 12:48:24,242 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:50:24,245 - root - INFO - Autosave.
# 2017-09-13 12:50:24,252 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:52:24,255 - root - INFO - Autosave.
# 2017-09-13 12:52:24,263 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:54:24,266 - root - INFO - Autosave.
# 2017-09-13 12:54:24,274 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:56:24,277 - root - INFO - Autosave.
# 2017-09-13 12:56:24,285 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 12:58:24,288 - root - INFO - Autosave.
# 2017-09-13 12:58:24,296 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:00:24,298 - root - INFO - Autosave.
# 2017-09-13 13:00:24,307 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:02:24,310 - root - INFO - Autosave.
# 2017-09-13 13:02:24,317 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:04:24,320 - root - INFO - Autosave.
# 2017-09-13 13:04:24,329 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:06:24,331 - root - INFO - Autosave.
# 2017-09-13 13:06:24,339 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:08:24,342 - root - INFO - Autosave.
# 2017-09-13 13:08:24,350 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:10:24,353 - root - INFO - Autosave.
# 2017-09-13 13:10:24,361 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:12:24,363 - root - INFO - Autosave.
# 2017-09-13 13:12:24,372 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:14:24,375 - root - INFO - Autosave.
# 2017-09-13 13:14:24,382 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:16:24,385 - root - INFO - Autosave.
# 2017-09-13 13:16:24,394 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:18:24,396 - root - INFO - Autosave.
# 2017-09-13 13:18:24,404 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:20:24,407 - root - INFO - Autosave.
# 2017-09-13 13:20:24,415 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:22:24,418 - root - INFO - Autosave.
# 2017-09-13 13:22:24,426 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:24:24,428 - root - INFO - Autosave.
# 2017-09-13 13:24:24,436 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:26:24,439 - root - INFO - Autosave.
# 2017-09-13 13:26:24,447 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:28:24,449 - root - INFO - Autosave.
# 2017-09-13 13:28:24,458 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:30:24,460 - root - INFO - Autosave.
# 2017-09-13 13:30:24,468 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:32:24,471 - root - INFO - Autosave.
# 2017-09-13 13:32:24,480 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:34:24,482 - root - INFO - Autosave.
# 2017-09-13 13:34:24,490 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:36:24,493 - root - INFO - Autosave.
# 2017-09-13 13:36:24,501 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:38:24,504 - root - INFO - Autosave.
# 2017-09-13 13:38:24,512 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:40:24,514 - root - INFO - Autosave.
# 2017-09-13 13:40:24,523 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:42:24,525 - root - INFO - Autosave.
# 2017-09-13 13:42:24,533 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:44:24,535 - root - INFO - Autosave.
# 2017-09-13 13:44:24,544 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:46:24,546 - root - INFO - Autosave.
# 2017-09-13 13:46:24,554 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:48:24,556 - root - INFO - Autosave.
# 2017-09-13 13:48:24,564 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:50:24,566 - root - INFO - Autosave.
# 2017-09-13 13:50:24,576 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:52:24,578 - root - INFO - Autosave.
# 2017-09-13 13:52:24,587 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:54:24,590 - root - INFO - Autosave.
# 2017-09-13 13:54:24,598 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:56:24,601 - root - INFO - Autosave.
# 2017-09-13 13:56:24,609 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 13:58:24,611 - root - INFO - Autosave.
# 2017-09-13 13:58:24,620 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:00:24,623 - root - INFO - Autosave.
# 2017-09-13 14:00:24,631 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:02:24,634 - root - INFO - Autosave.
# 2017-09-13 14:02:24,642 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:04:24,645 - root - INFO - Autosave.
# 2017-09-13 14:04:24,653 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:06:24,655 - root - INFO - Autosave.
# 2017-09-13 14:06:24,663 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:08:24,666 - root - INFO - Autosave.
# 2017-09-13 14:08:24,674 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:10:24,677 - root - INFO - Autosave.
# 2017-09-13 14:10:24,685 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:12:24,687 - root - INFO - Autosave.
# 2017-09-13 14:12:24,695 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:14:24,698 - root - INFO - Autosave.
# 2017-09-13 14:14:24,706 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:16:24,709 - root - INFO - Autosave.
# 2017-09-13 14:16:24,717 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:18:24,719 - root - INFO - Autosave.
# 2017-09-13 14:18:24,728 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:20:24,731 - root - INFO - Autosave.
# 2017-09-13 14:20:24,739 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:22:24,742 - root - INFO - Autosave.
# 2017-09-13 14:22:24,750 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:24:24,753 - root - INFO - Autosave.
# 2017-09-13 14:24:24,760 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:26:24,763 - root - INFO - Autosave.
# 2017-09-13 14:26:24,771 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:28:24,774 - root - INFO - Autosave.
# 2017-09-13 14:28:24,782 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:30:24,784 - root - INFO - Autosave.
# 2017-09-13 14:30:24,792 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:32:24,795 - root - INFO - Autosave.
# 2017-09-13 14:32:24,803 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:34:24,805 - root - INFO - Autosave.
# 2017-09-13 14:34:24,814 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:36:24,817 - root - INFO - Autosave.
# 2017-09-13 14:36:24,825 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:38:24,827 - root - INFO - Autosave.
# 2017-09-13 14:38:24,836 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:40:24,838 - root - INFO - Autosave.
# 2017-09-13 14:40:24,846 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:42:24,848 - root - INFO - Autosave.
# 2017-09-13 14:42:24,857 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:44:24,859 - root - INFO - Autosave.
# 2017-09-13 14:44:24,867 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:46:24,870 - root - INFO - Autosave.
# 2017-09-13 14:46:24,878 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:48:24,881 - root - INFO - Autosave.
# 2017-09-13 14:48:24,888 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:50:24,891 - root - INFO - Autosave.
# 2017-09-13 14:50:24,899 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:52:24,902 - root - INFO - Autosave.
# 2017-09-13 14:52:24,909 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:54:24,912 - root - INFO - Autosave.
# 2017-09-13 14:54:24,920 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:56:24,923 - root - INFO - Autosave.
# 2017-09-13 14:56:24,930 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 14:58:24,933 - root - INFO - Autosave.
# 2017-09-13 14:58:24,941 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:00:24,944 - root - INFO - Autosave.
# 2017-09-13 15:00:24,951 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:02:24,953 - root - INFO - Autosave.
# 2017-09-13 15:02:24,961 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:04:24,964 - root - INFO - Autosave.
# 2017-09-13 15:04:24,972 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:06:24,974 - root - INFO - Autosave.
# 2017-09-13 15:06:24,982 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:08:24,984 - root - INFO - Autosave.
# 2017-09-13 15:08:24,992 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:10:24,994 - root - INFO - Autosave.
# 2017-09-13 15:10:25,002 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:12:25,005 - root - INFO - Autosave.
# 2017-09-13 15:12:25,013 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:14:25,015 - root - INFO - Autosave.
# 2017-09-13 15:14:25,024 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:16:25,026 - root - INFO - Autosave.
# 2017-09-13 15:16:25,034 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:18:25,037 - root - INFO - Autosave.
# 2017-09-13 15:18:25,045 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:20:25,047 - root - INFO - Autosave.
# 2017-09-13 15:20:25,055 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:22:25,058 - root - INFO - Autosave.
# 2017-09-13 15:22:25,066 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:24:25,069 - root - INFO - Autosave.
# 2017-09-13 15:24:25,078 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:26:25,080 - root - INFO - Autosave.
# 2017-09-13 15:26:25,088 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:28:25,091 - root - INFO - Autosave.
# 2017-09-13 15:28:25,100 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:30:25,102 - root - INFO - Autosave.
# 2017-09-13 15:30:25,111 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:32:25,113 - root - INFO - Autosave.
# 2017-09-13 15:32:25,121 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:34:25,123 - root - INFO - Autosave.
# 2017-09-13 15:34:25,131 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:36:25,134 - root - INFO - Autosave.
# 2017-09-13 15:36:25,142 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:38:25,144 - root - INFO - Autosave.
# 2017-09-13 15:38:25,153 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:40:25,155 - root - INFO - Autosave.
# 2017-09-13 15:40:25,163 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:42:25,166 - root - INFO - Autosave.
# 2017-09-13 15:42:25,174 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:44:25,176 - root - INFO - Autosave.
# 2017-09-13 15:44:25,184 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:46:25,186 - root - INFO - Autosave.
# 2017-09-13 15:46:25,195 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
# 2017-09-13 15:48:25,197 - root - INFO - Autosave.
# 2017-09-13 15:48:25,205 - root - INFO - Saved. File path: ../data/defterms_dump/results/mnist_autosave.npy
